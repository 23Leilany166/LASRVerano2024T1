# %%
import CodeBase.Datos_frecuencias as simpleData 
import CodeBase.DatosDYC as dtDisc 
import CodeBase.DatosC as dtCont
import CodeBase.Graficas as graf 
import CodeBase.Tabla as tb
import math

# %% [markdown]
# # Ejercicio 15

# %%
datos15 = [
    "Ramírez", "Rodríguez", "Hernández", "Hernández", "Rodríguez", "Rodríguez", "González", "González", 
    "Ramírez", "Hernández", "García", "Martínez", "López", "González", "Martínez", "López", "López", 
    "González", "Gutiérrez", "Martínez", "González", "Rodríguez", "Pérez", "Rodríguez", "Ramírez", 
    "Sánchez", "Martínez", "López", "Sánchez", "García", "Rodríguez", "Hernández", "González", 
    "Sánchez", "Pérez", "Rodríguez", "López", "Martínez", "Flores", "Hernández", "Pérez", "García", 
    "Martínez", "Hernández", "Sánchez", "Ramírez", "García", "González", "García", "Flores", "Martínez", 
    "García", "Ramírez", "González", "Hernández", "López", "Sánchez", "Martínez", "Martínez", "Pérez", 
    "García", "González", "García", "Gutiérrez", "Hernández", "Martínez", "García", "Hernández", "García", 
    "González", "López", "Hernández", "Rodríguez", "Martínez", "González", "García", "Hernández", 
    "Ramírez", "Flores", "Hernández", "Gutiérrez", "García", "Hernández", "González", "García", "García", 
    "Flores", "López", "Pérez", "Sánchez", "López", "Gutiérrez", "Sánchez", "Rodríguez", "Hernández", 
    "Hernández", "Pérez", "Sánchez", "López", "Martínez"
]

# %%
# Datos
clases, fa, faAc, fr, frAc = dtDisc.generateQualitativeData(datos15)
frStr, frAcStr = tb.datosStrPorcentaje(fr, frAc)

# Tabla
encabezados = ["Clases", "Fa", "Fr", "Fr Acum"]
contenido = [clases, fa, frStr, frAcStr]
tb.printHTMLTable(encabezados, contenido)
# Out:
# <center><table><tr><th style='border: 1px #ccc solid; text-align: center;'>Clases</th><th style='border: 1px #ccc solid; text-align: center;'>Fa</th><th style='border: 1px #ccc solid; text-align: center;'>Fr</th><th style='border: 1px #ccc solid; text-align: center;'>Fr Acum</th></tr><tr><td style='border: 1px #ccc solid; text-align: center;'>gutiérrez</td><td style='border: 1px #ccc solid; text-align: center;'>4</td><td style='border: 1px #ccc solid; text-align: center;'>4.0%</td><td style='border: 1px #ccc solid; text-align: center;'>4.0%</td></tr><tr><td style='border: 1px #ccc solid; text-align: center;'>flores</td><td style='border: 1px #ccc solid; text-align: center;'>4</td><td style='border: 1px #ccc solid; text-align: center;'>4.0%</td><td style='border: 1px #ccc solid; text-align: center;'>8.0%</td></tr><tr><td style='border: 1px #ccc solid; text-align: center;'>ramírez</td><td style='border: 1px #ccc solid; text-align: center;'>6</td><td style='border: 1px #ccc solid; text-
# ...

# %%
# Gráficas
graf.Diagrama_Barras(clases, fa)

# %% [markdown]
# # Ejercicio 7

# %%
# Datos Iniciales
datos7 = [
    'Pumas','América','Chivas','Pumas','Chivas','Chivas','América','Toluca','Toluca','Pumas',
    'Santos','Necaxa','América','América','América','Pumas','Santos','Pumas','Pumas','Pumas',
    'América','Chivas','América','Pumas','Necaxa','Toluca','Chivas','América','Toluca','Santos'
]

# %%
# Datos
clases, fa, faAc, fr, frAc = dtDisc.generateQualitativeData(datos7)
frStr, frAcStr = tb.datosStrPorcentaje(fr, frAc)

# Tabla
encabezados = ["Clases", "Fa", "Fr", "Fr Acum"]
contenido = [clases, fa, frStr, frAcStr]
tb.printHTMLTable(encabezados, contenido)
# Out:
# <center><table><tr><th style='border: 1px #ccc solid; text-align: center;'>Clases</th><th style='border: 1px #ccc solid; text-align: center;'>Fa</th><th style='border: 1px #ccc solid; text-align: center;'>Fr</th><th style='border: 1px #ccc solid; text-align: center;'>Fr Acum</th></tr><tr><td style='border: 1px #ccc solid; text-align: center;'>necaxa</td><td style='border: 1px #ccc solid; text-align: center;'>2</td><td style='border: 1px #ccc solid; text-align: center;'>6.667%</td><td style='border: 1px #ccc solid; text-align: center;'>6.667%</td></tr><tr><td style='border: 1px #ccc solid; text-align: center;'>santos</td><td style='border: 1px #ccc solid; text-align: center;'>3</td><td style='border: 1px #ccc solid; text-align: center;'>10.0%</td><td style='border: 1px #ccc solid; text-align: center;'>16.667%</td></tr><tr><td style='border: 1px #ccc solid; text-align: center;'>toluca</td><td style='border: 1px #ccc solid; text-align: center;'>4</td><td style='border: 1px #ccc solid; t
# ...

# %%
# Gráficas
graf.Diagrama_Barras(clases, fa)
graf.Diagrama_pastel(clases, fa, fr)

# %% [markdown]
# # Ejercicio 8

# %%
datos8 = [
    2.5,4.5,5.8,2.2,5.7,5.3,4.0,0.9,2.5,2.3,3.2,4.9,2.7,3.7,3.8,4.9,2.8,3.6,4.2,3.1,7.2,1.9,5.9,3.3,2.9,1.1,1.7,2.6,3.1,4.4
]

# %%
#Respuesta pregunta a
print("a) Los datos que estamos manejando en el progrma son datos continuuos")
# Out:
# a) Los datos que estamos manejando en el progrma son datos continuuos

# %%
print("Los datos que tiene el problemas son 30 datos en total.")
# Out:
# Los datos que tiene el problemas son 30 datos en total.

# %%
clases, limsInf, limsSup, mrksClases, fa, fr, frAc = dtCont.generateGroupedData(datos8,1,6)
frStr, frAcStr = tb.datosStrPorcentaje(fr, frAc)

encabezados = ["Clases", "Límites inferiores", "Límites superiores", "Marca de clase", "Fa", "Fr", "FrAcum."]
contenido = [clases, limsInf, limsSup, mrksClases, fa, frStr, frAcStr]
tb.printHTMLTable(encabezados, contenido)
# Out:
# <center><table><tr><th style='border: 1px #ccc solid; text-align: center;'>Clases</th><th style='border: 1px #ccc solid; text-align: center;'>Límites inferiores</th><th style='border: 1px #ccc solid; text-align: center;'>Límites superiores</th><th style='border: 1px #ccc solid; text-align: center;'>Marca de clase</th><th style='border: 1px #ccc solid; text-align: center;'>Fa</th><th style='border: 1px #ccc solid; text-align: center;'>Fr</th><th style='border: 1px #ccc solid; text-align: center;'>FrAcum.</th></tr><tr><td style='border: 1px #ccc solid; text-align: center;'>1</td><td style='border: 1px #ccc solid; text-align: center;'>0.9</td><td style='border: 1px #ccc solid; text-align: center;'>1.95</td><td style='border: 1px #ccc solid; text-align: center;'>1.425</td><td style='border: 1px #ccc solid; text-align: center;'>4</td><td style='border: 1px #ccc solid; text-align: center;'>13.333%</td><td style='border: 1px #ccc solid; text-align: center;'>13.333%</td></tr><tr><td style='b
# ...

# %%
clases = 1 + (3.3*math.log10(len(datos8)))
print(clases)
# Out:
# 5.874500140574885

# %%
graf.Histograma(mrksClases, fr) 
graf.Ojiva(mrksClases, frAc)

# %% [markdown]
# # Ejercicio 12

# %%
# Datos Iniciales
datosEj12 = [
    250,790,470,510,500,330,300,750,580,740,420,260,440,770,400,540,530,330,390,380,340,460,530,260,410,360,270,510,630,330
]

# %%
# Respuesta a
print("a. Los datos manejados en este problema son Continuos")
# Out:
# a. Los datos manejados en este problema son Continuos

# %%
print(sum(fa))
# Out:
# 30

# %%
# Datos
clases, limsInf, limsSup, mrksClases, fa, fr, frAc = dtCont.generateGroupedData(datosEj12,2,6)
frStr, frAcStr = tb.datosStrPorcentaje(fr, frAc)
# Tabla
encabezados = ["Clases", "Límites inferiores", "Límites superiores", "Marca de clase", "Fa", "Fr", "FrAcum."]
contenido = [clases, limsInf, limsSup, mrksClases, fa, frStr, frAcStr]
tb.printHTMLTable(encabezados, contenido)
# Out:
# 30
# ...

# %%
# Gráficas
graf.Histograma(mrksClases, fr) 
graf.Ojiva(mrksClases, frAc)

# %% [markdown]
# # Ejercicio 15
